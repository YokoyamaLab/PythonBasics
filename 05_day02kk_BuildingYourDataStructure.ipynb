# %% [markdown]
# <a href="https://colab.research.google.com/github/YokoyamaLab/PythonBasics/blob/2025/05_day02kk_BuildingYourDataStructure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ノート05**
# # [Day02 講義内課題] 辞書型のデータをリストする

# %%
# @title 提出者情報
学籍番号 = "" # @param {"type":"string"}
名前 = "" # @param {"type":"string"}

# %% [markdown]
# ## お題

# %% [markdown]
# *  要素が辞書型であるリストをつくる。
# *  内容は皆さんの身の回りの情報を使って作ってください。
#   *  お気に入りのカフェのリスト
#   * 今期とっている講義のリスト　etc…..
# * 見やすいようにpprintで出力してください
#   * やり方は予習テキストにあります
# * 次回以降「ソート」の題材にするので数値データが含んでいると良いです
# * 最低限、リストの長さは10欲しいです

# %% [markdown]
# ## 解答欄

# %% [markdown]
# ### コードの説明はこちら

# %% [markdown]
# > ここにコードの説明をかく
