# %% [markdown]
# <a href="https://colab.research.google.com/github/YokoyamaLab/PythonBasics/blob/2025/08_day01hw_Operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ノート08**
#
# # [Day01 Homework] 演算子を使いこなそう

# %% [markdown]
# > 制御構文については次回講義内課題で触れますので宿題としては演算子の使い方を学びましょう。

# %%
#@title 学籍番号、名前
id = "" #@param {type:"string"}
name = "" #@param {type:"string"}

# %% [markdown]
# ## 課題
#
# 以下の方程式の答えを解の公式で求めよ。
#
# $$
# x^2+2x+3=0
# $$
#
# 入力を汎用化するために以下のa、b、cを変数として準備し、そこから始めましょう。
#
# $$
# ax^2+b+x+c=0
# $$
#
# 解の公式覚えていますよね？
#
# $$
# x_1 =\frac{-b+\sqrt{b^2-4ac}}{2a}, x_2 =\frac{-b-\sqrt{b^2-4ac}}{2a}
# $$
#
# では以下のコードブロックに作成してください。

# %%
# 方程式の定義
a = 1
b = 2
c = 3
# 結果はx1,x2に代入せよ
x1 = None
x2 = None
