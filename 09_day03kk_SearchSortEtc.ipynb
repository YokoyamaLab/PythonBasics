# %% [markdown]
# <a href="https://colab.research.google.com/github/YokoyamaLab/PythonBasics/blob/2025/09_day03kk_SearchSortEtc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ノート09**
#
# # [Day03 講義内課題] 辞書型のデータをリストする

# %%
# @title 提出者情報
学籍番号 = "" # @param {"type":"string"}
名前 = "" # @param {"type":"string"}

# %% [markdown]
# ## お題

# %% [markdown]
# * 前回作った辞書型のリストを使います。
# * これをfor文やwhile文で各要素を見て、検索やソートをする
# * 与えられキーワードを持つ要素のみ出力する
# * 与えられた数値以上/以下の要素のみ出力する
# * 各要素が持つ数値でソートする
# * 各要素が持つ文字列でソートする
# * などなど・・・・（他、演算子や制御構文を使って何を作ってもOK）

# %% [markdown]
# ## 対象データ

# %%
# 前回作ったリストをここへコピペしましょう

# %% [markdown]
# ## 解答欄

# %%
# 例えば・・・

keyeord = "hogehoge"

# データ中からkeywordで指定された文字列を持つ要素を探すコード
# 等、学んだ事を活かして、リストを『どうのこうの』するプログラムを実装してください

# %% [markdown]
# ### コードの説明はこちら

# %% [markdown]
# > ここにコードの説明をかく
