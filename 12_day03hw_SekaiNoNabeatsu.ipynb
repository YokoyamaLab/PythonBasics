# %% [markdown]
# <a href="https://colab.research.google.com/github/YokoyamaLab/PythonBasics/blob/2025/12_day03hw_SekaiNoNabeatsu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ノート12**
#
# # [Day03 Homework] 三の倍数か三のつく数でアホになる

# %%
#@title 学籍番号、名前
学籍番号 = "" #@param {type:"string"}
名前 = "" #@param {type:"string"}

# %% [markdown]
# ## 課題
#
# **ランダムな数字からなるリストをMapで処理し、3の倍数か3が付く数の時だけ、🤪アホな顔が数字の後ろに付くプログラムを実装せよ**
#
# 以下、順に実装・実行を進めてください。まず、以下のコードでランダムなリストを生成します。

# %%
import random
in_list = random.sample(range(1,50), k=30)
print(in_list)

# %% [markdown]
# **in_list**は長さ30の1～50までの整数を持つリストです。これを3の倍数か3が付く数の時だけ数字の後ろにアホな顔をくっつけて、新しいリスト**out_list**に格納してください。
#
# なお、53という数字に3が含まれているか調べるには、一度**str()**関数で文字列型にしてから**in**を使って調べられます。3の倍数かは3で割った余りで調べられるので、それをorで結ぶと、題意を満たす条件文が作れます。

# %%
n53 = 53
n52 = 52
n51 = 51
print( '3' in str(n53) or n53 % 3 == 0) # 3の倍数ではないが3がつく数 ---> true
print( '3' in str(n52) or n52 % 3 == 0) # 3の倍数でも3がつく数でもない -> false
print( '3' in str(n51) or n51 % 3 == 0) # 3はつかないが3の倍数の数 -----> true

# %% [markdown]
# まず引数で与えられた数```n```が3の場合数か3のつく数の場合、数字の後ろにアホな顔🤪をつけて返し、それ以外の時は数をそのまま返す関数```nabeatsu(n)```を実装してください。
#
# ちなみに、三項演算子を使って一行で書けますよ。
#
# ちなみに②、コード生成AIを使えば一発で出てきますが、まずは皆さんの頭で考えてみることを強くお勧めします。

# %%
def nabeatsu(n):
  # 以下のコードを題意を満たすよう置き換えてください。
  return n

# %% [markdown]
# これで素材はそろったのでmap関数を使って、in_listの各数字で3の倍数か3のつく数の時、数字に加えてアホな顔を付与したリストを生成するコードを実装してください。下記のout_listに結果が格納されればOKです。

# %%
# 以下のmapの引数を題意を満たすように書き込んでください
out_list = map()

# %% [markdown]
# 以下のコードでout_listを確認して、正しければ提出してください。
#
# 3のつく数か3の倍数の時、例えば```33🤪```となっている事が期待されます。

# %%
print(in_list)
print(out_list)
