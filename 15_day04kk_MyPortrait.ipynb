# %% [markdown]
# <a href="https://colab.research.google.com/github/YokoyamaLab/PythonBasics/blob/2025/15_day04kk_MyPortrait.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ノート15**
#
# # [Day04 講義内課題] 似顔絵の作成

# %%
# @title 提出者情報
学籍番号 = "" # @param {"type":"string"}
名前 = "" # @param {"type":"string"}

# %% [markdown]
# ## お題

# %% [markdown]
# - 以下の要件に基づいて皆さんの似顔絵を作ってください
# 	- SelfPortraitクラスを継承してMyPortraitクラスを作成
# 	- 顔のパーツを描くメソッドを一部or全部オーバーライドして自分に似せる
# 		- 出来る限りね
# 	- インスタンスを作成し描画を実行してきちんと顔が描ける事を確認
# 	- ノート最下部にある似顔絵画像保存コードを必ず実行してください。
# 		- Google Driveの使用許可がでるので「許可」してください
# 	- Google Classroomで提出

# %% [markdown]
# ## 前準備

# %%
# ベースとなるSelfPortraitクラスのインストール
# !pip install "git+https://github.com/YokoyamaLab/PythonBasics.git@2025#egg=self_portrait&subdirectory=lib"

# %%
# PILで日本語を使う場合はフォントのインストール
# !wget -P /usr/share/fonts/ https://github.com/YokoyamaLab/PythonBasics/raw/refs/heads/2025/font/NotoSansCJKjp-DemiLight.ttf
cjk_font_path = "/usr/share/fonts/NotoSansCJKjp-DemiLight.ttf"

# %%
# SelfPortraitクラスのインポート
from self_portrait import SelfPortrait

# %% [markdown]
# ## 解答欄 (SelfPortraitクラスを継承したMyPortraitクラスの実装)

# %%
# クラスの定義
class MyPortrait(SelfPortrait):
  pass # passに変えて、皆さんのコードをここに書いてください。

# %%
# インスタンスの作成と描画実行
myPortrait = MyPortrait("Your Name") # 名前は皆さん自身の名前に変更してください。(アルファベットで)
image = myPortrait.draw()
#必ずimage変数に結果を格納してください。
image

# %% [markdown]
# ## 画像の保存

# %% [markdown]
# 結果を画像ファイルでGoogle Driveに保存します。保存された皆さんの似顔絵は[こちら](https://drive.google.com/file/d/1-3mI78MCpjrDuL6nadP1j9PVvenR-u35/view?usp=drive_link)で参照できます。
#
# まず以下のコードブロックを実行してGoogle DriveをColaboに接続しましょう。

# %%
from google.colab import drive
drive.mount("/content/gdrive")
our_dir = "/content/gdrive/Shareddrives/2025-LG080A01／情報科学 c/portrait"

# %% [markdown]
# そして以下を実行して、imageをpngファイルで保存しましょう。

# %%
if (学籍番号 == ""):
  print("ERROR!: ノート冒頭の学籍番号を入力して実行もしてください。")
else:
  image.save(our_dir + "/" + 学籍番号 + '.png')

# %% [markdown]
# ここまで終えたら、Classroomでも提出してください。
