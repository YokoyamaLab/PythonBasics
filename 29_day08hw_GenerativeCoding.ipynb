# %% [markdown]
# <a href="https://colab.research.google.com/github/YokoyamaLab/PythonBasics/blob/2025/29_day08hw_GenerativeCoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ノート29
#
# # [Day08 Homework] 自由課題（生成AIをフル活用して簡単に複雑な事をしてください）
