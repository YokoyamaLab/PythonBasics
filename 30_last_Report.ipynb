# %% [markdown]
# <a href="https://colab.research.google.com/github/YokoyamaLab/PythonBasics/blob/2025/30_last_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ノート30
#
# # [情報科学C 最終課題] 自由課題

# %%
# @title 提出者情報
No = "" # @param {"type":"string","placeholder":"学籍番号"}
名前 = "" # @param {"type":"string","placeholder":"名前"}

# %% [markdown]
# - 実データに対して機械学習を使った上で結果を可視化する
#     - 実データは統計データでも身の回りのデータでも構いません
#     - 生成AIでのデータは避けてください。
#     - データをこねくり回すのではなく意味のある知見の発見をめざす
#
# - チェックリスト
#   - NumPyをつかう(必須)
#   - Pandasをつかう
#   - Matplotlibあるいはそれより高度な可視化ライブラリを使う(必須)
#   - 機械学習を使う(優・秀をめざすなら必須)
#   - プラスアルファがある(優・秀をめざすなら必須)
#
#   レポートはこの下に自由に作成してください。あくまでレポートですので、結果の貼り付けだけでなく、説明の為の文章も豊富につけてください。
