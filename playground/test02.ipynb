# %% [markdown]
# <a href="https://colab.research.google.com/github/YokoyamaLab/PythonBasics/blob/main/playground/test02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PDFの特定ページを表示する例

# %%
# %%capture
# !apt-get install poppler-utils
# !pip install pdf2image
import requests,pdf2image
pdf = requests.get('https://github.com/YokoyamaLab/PythonBasics/raw/main/playground/test02.pdf', stream=True)
images = pdf2image.convert_from_bytes(pdf.raw.read())

# %%
images[0]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2667x1500 at 0x7F342393B210>
